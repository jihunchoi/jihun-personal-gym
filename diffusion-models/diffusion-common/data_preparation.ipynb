# %%
from torchvision.datasets import CelebA

# %%
from pathlib import Path

dataset_root = Path.cwd().parent / 'datasets'

# %%
CelebA(root=dataset_root, split="all", download=True)
# Out:
# Dataset CelebA
#     Number of datapoints: 202599
#     Root location: /Users/jihun/Library/Mobile Documents/com~apple~CloudDocs/Workspace/jihun-personal-gym/diffusion-models/datasets
#     Target type: ['attr']
#     Split: all
